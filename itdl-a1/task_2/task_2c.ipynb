# %%
import numpy as np 
import gc
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, Input
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# %%
def preprocess_data(data, labels):
    data = data / 255.0

    hour_labels = labels[:, 0]
    minute_labels = labels[:, 1]

    hour_labels_one_hot = tf.keras.utils.to_categorical(hour_labels, num_classes=12)

    minute_labels = minute_labels.reshape(-1, 1)

    if len(data.shape) == 3:
        data = data.reshape(-1, data.shape[1], data.shape[2], 1)
    
    data_train, data_temp, hour_train, hour_temp, minute_train, minute_temp = train_test_split(
        data, hour_labels_one_hot, minute_labels, test_size=0.2, random_state=42, shuffle=True
    )
    
    data_val, data_test, hour_val, hour_test, minute_val, minute_test = train_test_split(
        data_temp, hour_temp, minute_temp, test_size=0.5, random_state=42
    )
    
    labels_train = {'hour_output': hour_train, 'minute_output': minute_train}
    labels_val = {'hour_output': hour_val, 'minute_output': minute_val}
    labels_test = {'hour_output': hour_test, 'minute_output': minute_test}
    
    return data_train, labels_train, data_test, labels_test, data_val, labels_val


def common_sense_metric_minute(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.math.mod(y_pred, 60.0)
    linear_diff = tf.abs(y_true - y_pred)
    circular_diff = tf.minimum(linear_diff, 60.0 - linear_diff)

    return tf.reduce_mean(circular_diff)


def common_sense_loss_minute(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.math.mod(y_pred, 60.0)
    linear_diff = tf.abs(y_true - y_pred)
    circular_diff = tf.minimum(linear_diff, 60.0 - linear_diff)
    
    return tf.reduce_mean(tf.square(circular_diff))


def plot_hour_accuracy(history):
    accuracy = history.history['hour_output_accuracy']
    val_accuracy = history.history['val_hour_output_accuracy']
    
    plt.figure(figsize=(8, 6))
    plt.plot(accuracy, label='Training accuracy')
    plt.plot(val_accuracy, label='Validation accuracy')
    plt.title('Training and validation accuracy on hour prediction')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    plt.show()
    

def plot_minute_mae(history):
    mae = history.history.get('minute_output_common_sense_metric_minute') 
    val_mae = history.history.get('val_minute_output_common_sense_metric_minute') 
    
    if mae is None or val_mae is None:
        raise ValueError("MAE metrics not found in history object. Available keys are: {}".format(history.history.keys()))
    
    
    plt.figure(figsize=(8, 6))
    plt.plot(mae, label='Training common sense error')
    plt.plot(val_mae, label='Validation common sense error')
    plt.title('Training and validation common sense error on minute prediction')
    plt.xlabel('Epochs')
    plt.ylabel('Common sense error')
    plt.legend()
    plt.grid(True)
    plt.show()


def plot_error_distribution(y_true, predictions, num_bins=30):
    hour_pred_probs = predictions['hour_output']
    hour_pred_classes = np.argmax(hour_pred_probs, axis=1)  # Class labels (0-11)
    minute_pred = predictions['minute_output'].flatten()

    hour_true_one_hot = y_true['hour_output']
    hour_true_classes = np.argmax(hour_true_one_hot, axis=1)
    minute_true = y_true['minute_output'].flatten()

    minute_pred = np.mod(minute_pred, 60.0)
    hour_pred_classes = np.mod(hour_pred_classes, 12.0)

    time_pred = hour_pred_classes * 60.0 + minute_pred
    time_true = hour_true_classes * 60.0 + minute_true
    
    error = tf.abs(time_pred - time_true)
    absolute_error = tf.minimum(error, 720.0 - error)

    # for i in range(len(time_pred)):
    #     print(f"y_true: {time_true[i]}, hour_pred: {hour_pred_classes[i]}, minute_pred: {minute_pred[i]}, linear_diff: {error[i]}, circular_error: {absolute_error[i]}")

    plt.figure(figsize=(10, 6))
    plt.hist(absolute_error, bins=num_bins, color='skyblue', edgecolor='black')
    plt.title('Distribution of common sense errors')
    plt.xlabel('Common sense error (minutes)')
    plt.ylabel('Frequency')
    plt.yscale('log')
    plt.xticks([0,60,120,180,240,300,360])
    plt.grid(True)
    plt.show()

    plt.figure(figsize=(10, 6))
    plt.hist(absolute_error, bins=num_bins, color='skyblue', edgecolor='black')
    plt.title('Distribution of common sense errors')
    plt.xlabel('Common sense error (minutes)')
    plt.ylabel('Frequency')
    plt.xticks([0,60,120,180,240,300,360])
    plt.grid(True)
    plt.show()

    mae = mean_absolute_error(time_true, time_pred)
    rmse = np.sqrt(mean_squared_error(time_true, time_pred))

    print(f"Common Sense Error (CSE): {mae:.2f} minutes")

# %%
def create_multi_head_model(image_length, data, labels):
    tf.keras.backend.clear_session()
    gc.collect()
    data_train, labels_train, data_test, labels_test, data_val, labels_val = preprocess_data(data, labels)

    # Input layer
    input_layer = Input(shape=(image_length, image_length, 1))

    # Shared base: Convolutional layers
    # Layer 0
    x = Conv2D(32, (3, 3), activation='relu')(input_layer)
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    # Layer 1
    x = Conv2D(64, (3, 3), activation='relu')(x)    
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    # Layer 2
    x = Conv2D(128, (3, 3), activation='relu')(x)    
    x = MaxPooling2D((2, 2))(x)
    x = Dropout(0.4)(x)
    x = Flatten()(x)

    # Head 1: Predict hour components (classification)
    x = Dense(128, activation='relu',kernel_regularizer=l2(0.001))(x)
    head1 = Dropout(0.4)(x)
    head1_output = Dense(12, activation='softmax', name='hour_output')(head1)

    # Head 2: Predict minute components (regression)
    head2 = Dense(64, activation='relu')(x)
    head2_output = Dense(1, name='minute_output')(head2)

    model = Model(inputs=input_layer, outputs={'hour_output': head1_output, 'minute_output': head2_output})

    optimizer = Adam(learning_rate=1e-4)

    model.summary()

    model.compile(
        optimizer=optimizer,
        loss={'hour_output': 'categorical_crossentropy', 'minute_output': common_sense_loss_minute},
        loss_weights={'hour_output': 12.0, 'minute_output': 0.01},
        metrics={'hour_output': 'accuracy', 'minute_output': common_sense_metric_minute}
    )

    history = model.fit(
        data_train,
        {'hour_output': labels_train['hour_output'], 'minute_output': labels_train['minute_output']},
        epochs=1000,
        batch_size=32,
        validation_data=(data_val, {'hour_output': labels_val['hour_output'], 'minute_output': labels_val['minute_output']})
    )

    results = model.evaluate(data_test, labels_test, return_dict=True)

    return model, history, results, data_test, labels_test


def run(image_size=150):
    if image_size == 75: 
        data = np.load('../clocks_small/images.npy')
        labels = np.load('../clocks_small/labels.npy')
    elif image_size == 150:
        data = np.load('../clocks_large/images.npy')
        labels = np.load('../clocks_large/labels.npy')

    model, history, results, data_test, labels_test = create_multi_head_model(image_size, data, labels)

    # Evaluation results
    total_loss = results['loss']
    hour_loss = results['hour_output_loss']
    minute_loss = results['minute_output_loss']
    hour_accuracy = results['hour_output_accuracy']
    minute_mae = results['minute_output_common_sense_metric_minute']

    print(f"Test Loss: {total_loss}")
    print(f"Hour Loss: {hour_loss}, Hour Accuracy: {hour_accuracy}")
    print(f"Minute Loss: {minute_loss}, Minute CSE: {minute_mae}")

    predictions = model.predict(data_test)
    plot_hour_accuracy(history)    
    plot_minute_mae(history)
    plot_error_distribution(labels_test, predictions)


run(75)
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 75, 75, 1) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 73, 73,    │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 36, 36,    │          0 │ conv2d[0][0]      │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 36, 36,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 34, 34,    │     18,496 │ dropout[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 17, 17,    │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 17, 17,    │          0 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 15, 15,    │     73,856 │ dropout_1[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 7, 7, 128) │          0 │ conv2d_2[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 7, 7, 128) │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 6272)      │          0 │ dropout_2[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │    802,944 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 128)       │          0 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 64)        │      8,256 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ hour_output (Dense) │ (None, 12)        │      1,548 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ minute_output       │ (None, 1)         │         65 │ dense_1[0][0]     │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 905,485 (3.45 MB)
#  Trainable params: 905,485 (3.45 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - hour_output_accuracy: 0.0796 - hour_output_loss: 30.0086 - loss: 33.2690 - minute_output_common_sense_metric_minute: 15.0266 - minute_output_loss: 3.0138 - val_hour_output_accuracy: 0.0844 - val_hour_output_loss: 29.8188 - val_loss: 32.9749 - val_minute_output_common_sense_metric_minute: 14.8231 - val_minute_output_loss: 2.9493
# Epoch 2/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0828 - hour_output_loss: 29.8326 - loss: 33.1147 - minute_output_common_sense_metric_minute: 15.1180 - minute_output_loss: 3.0470 - val_hour_output_accuracy: 0.0806 - val_hour_output_loss: 29.8183 - val_loss: 32.9615 - val_minute_output_common_sense_metric_minute: 14.8228 - val_minute_output_loss: 2.9491
# Epoch 3/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0835 - hour_output_loss: 29.8258 - loss: 33.0677 - minute_output_common_sense_metric_minute: 15.0331 - minute_output_loss: 3.0194 - val_hour_output_accuracy: 0.0789 - val_hour_output_loss: 29.8191 - val_loss: 32.9483 - val_minute_output_common_sense_metric_minute: 14.8224 - val_minute_output_loss: 2.9488
# Epoch 4/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0820 - hour_output_loss: 29.8262 - loss: 33.0645 - minute_output_common_sense_metric_minute: 15.1020 - minute_output_loss: 3.0297 - val_hour_output_accuracy: 0.0878 - val_hour_output_loss: 29.8200 - val_loss: 32.9345 - val_minute_output_common_sense_metric_minute: 14.8221 - val_minute_output_loss: 2.9486
# Epoch 5/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0878 - hour_output_loss: 29.8200 - loss: 33.0510 - minute_output_common_sense_metric_minute: 15.1227 - minute_output_loss: 3.0368 - val_hour_output_accuracy: 0.0911 - val_hour_output_loss: 29.8186 - val_loss: 32.9184 - val_minute_output_common_sense_metric_minute: 14.8217 - val_minute_output_loss: 2.9483
# Epoch 6/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0827 - hour_output_loss: 29.8246 - loss: 33.0277 - minute_output_common_sense_metric_minute: 15.0534 - minute_output_loss: 3.0237 - val_hour_output_accuracy: 0.0800 - val_hour_output_loss: 29.8196 - val_loss: 32.9040 - val_minute_output_common_sense_metric_minute: 14.8214 - val_minute_output_loss: 2.9481
# Epoch 7/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0850 - hour_output_loss: 29.8164 - loss: 32.9780 - minute_output_common_sense_metric_minute: 15.0098 - minute_output_loss: 2.9974 - val_hour_output_accuracy: 0.0778 - val_hour_output_loss: 29.8197 - val_loss: 32.8886 - val_minute_output_common_sense_metric_minute: 14.8210 - val_minute_output_loss: 2.9480
# Epoch 8/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0832 - hour_output_loss: 29.8215 - loss: 32.9691 - minute_output_common_sense_metric_minute: 14.9875 - minute_output_loss: 2.9995 - val_hour_output_accuracy: 0.0794 - val_hour_output_loss: 29.8199 - val_loss: 32.8722 - val_minute_output_common_sense_metric_minute: 14.8208 - val_minute_output_loss: 2.9479
# Epoch 9/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0803 - hour_output_loss: 29.8217 - loss: 32.9581 - minute_output_common_sense_metric_minute: 15.0187 - minute_output_loss: 3.0042 - val_hour_output_accuracy: 0.0783 - val_hour_output_loss: 29.8196 - val_loss: 32.8560 - val_minute_output_common_sense_metric_minute: 14.8205 - val_minute_output_loss: 2.9478
# Epoch 10/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0826 - hour_output_loss: 29.8181 - loss: 32.9201 - minute_output_common_sense_metric_minute: 14.9918 - minute_output_loss: 2.9857 - val_hour_output_accuracy: 0.0911 - val_hour_output_loss: 29.8194 - val_loss: 32.8403 - val_minute_output_common_sense_metric_minute: 14.8202 - val_minute_output_loss: 2.9477
# Epoch 11/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0839 - hour_output_loss: 29.8191 - loss: 32.9068 - minute_output_common_sense_metric_minute: 14.9689 - minute_output_loss: 2.9866 - val_hour_output_accuracy: 0.0917 - val_hour_output_loss: 29.8186 - val_loss: 32.8244 - val_minute_output_common_sense_metric_minute: 14.8198 - val_minute_output_loss: 2.9476
# Epoch 12/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0851 - hour_output_loss: 29.8167 - loss: 32.8927 - minute_output_common_sense_metric_minute: 14.9826 - minute_output_loss: 2.9894 - val_hour_output_accuracy: 0.1017 - val_hour_output_loss: 29.7926 - val_loss: 32.7856 - val_minute_output_common_sense_metric_minute: 14.8164 - val_minute_output_loss: 2.9467
# Epoch 13/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.0946 - hour_output_loss: 29.7012 - loss: 32.7999 - minute_output_common_sense_metric_minute: 15.0796 - minute_output_loss: 3.0236 - val_hour_output_accuracy: 0.1300 - val_hour_output_loss: 28.9352 - val_loss: 31.8191 - val_minute_output_common_sense_metric_minute: 14.4118 - val_minute_output_loss: 2.8264
# Epoch 14/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.1198 - hour_output_loss: 28.8308 - loss: 31.6813 - minute_output_common_sense_metric_minute: 14.2488 - minute_output_loss: 2.7762 - val_hour_output_accuracy: 0.1661 - val_hour_output_loss: 27.6141 - val_loss: 30.1049 - val_minute_output_common_sense_metric_minute: 13.0499 - val_minute_output_loss: 2.4395
# Epoch 15/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.1595 - hour_output_loss: 27.7095 - loss: 30.2233 - minute_output_common_sense_metric_minute: 13.1303 - minute_output_loss: 2.4340 - val_hour_output_accuracy: 0.2061 - val_hour_output_loss: 26.3418 - val_loss: 28.6008 - val_minute_output_common_sense_metric_minute: 12.2417 - val_minute_output_loss: 2.2036
# Epoch 16/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.1828 - hour_output_loss: 26.6699 - loss: 28.9753 - minute_output_common_sense_metric_minute: 12.3441 - minute_output_loss: 2.2202 - val_hour_output_accuracy: 0.2167 - val_hour_output_loss: 25.2803 - val_loss: 27.4180 - val_minute_output_common_sense_metric_minute: 11.8677 - val_minute_output_loss: 2.0744
# Epoch 17/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.1963 - hour_output_loss: 25.9693 - loss: 28.1937 - minute_output_common_sense_metric_minute: 12.1433 - minute_output_loss: 2.1354 - val_hour_output_accuracy: 0.2433 - val_hour_output_loss: 24.5769 - val_loss: 26.7063 - val_minute_output_common_sense_metric_minute: 11.8520 - val_minute_output_loss: 2.0704
# Epoch 18/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2108 - hour_output_loss: 25.3899 - loss: 27.6212 - minute_output_common_sense_metric_minute: 12.1480 - minute_output_loss: 2.1386 - val_hour_output_accuracy: 0.2428 - val_hour_output_loss: 24.1903 - val_loss: 26.2612 - val_minute_output_common_sense_metric_minute: 11.6478 - val_minute_output_loss: 1.9876
# Epoch 19/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2284 - hour_output_loss: 24.8926 - loss: 27.0177 - minute_output_common_sense_metric_minute: 11.7941 - minute_output_loss: 2.0289 - val_hour_output_accuracy: 0.2689 - val_hour_output_loss: 23.5673 - val_loss: 25.6438 - val_minute_output_common_sense_metric_minute: 11.6438 - val_minute_output_loss: 2.0030
# Epoch 20/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2257 - hour_output_loss: 24.4338 - loss: 26.5427 - minute_output_common_sense_metric_minute: 11.6335 - minute_output_loss: 2.0081 - val_hour_output_accuracy: 0.2839 - val_hour_output_loss: 22.8197 - val_loss: 24.8574 - val_minute_output_common_sense_metric_minute: 11.5550 - val_minute_output_loss: 1.9719
# Epoch 21/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2420 - hour_output_loss: 24.0453 - loss: 26.1850 - minute_output_common_sense_metric_minute: 11.7622 - minute_output_loss: 2.0342 - val_hour_output_accuracy: 0.3050 - val_hour_output_loss: 22.3164 - val_loss: 24.3498 - val_minute_output_common_sense_metric_minute: 11.5068 - val_minute_output_loss: 1.9650
# Epoch 22/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2590 - hour_output_loss: 23.4380 - loss: 25.5471 - minute_output_common_sense_metric_minute: 11.6222 - minute_output_loss: 1.9987 - val_hour_output_accuracy: 0.3033 - val_hour_output_loss: 21.8876 - val_loss: 23.8950 - val_minute_output_common_sense_metric_minute: 11.4521 - val_minute_output_loss: 1.9180
# Epoch 23/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2782 - hour_output_loss: 22.8598 - loss: 24.9058 - minute_output_common_sense_metric_minute: 11.4226 - minute_output_loss: 1.9306 - val_hour_output_accuracy: 0.3233 - val_hour_output_loss: 21.1388 - val_loss: 23.1106 - val_minute_output_common_sense_metric_minute: 11.2797 - val_minute_output_loss: 1.8759
# Epoch 24/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.2822 - hour_output_loss: 22.3914 - loss: 24.4400 - minute_output_common_sense_metric_minute: 11.3749 - minute_output_loss: 1.9274 - val_hour_output_accuracy: 0.3656 - val_hour_output_loss: 20.5077 - val_loss: 22.4968 - val_minute_output_common_sense_metric_minute: 11.1750 - val_minute_output_loss: 1.8715
# Epoch 25/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3040 - hour_output_loss: 21.9464 - loss: 23.9674 - minute_output_common_sense_metric_minute: 11.2842 - minute_output_loss: 1.8941 - val_hour_output_accuracy: 0.3733 - val_hour_output_loss: 19.8470 - val_loss: 21.7829 - val_minute_output_common_sense_metric_minute: 10.9888 - val_minute_output_loss: 1.8257
# Epoch 26/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3189 - hour_output_loss: 21.3776 - loss: 23.3620 - minute_output_common_sense_metric_minute: 11.1220 - minute_output_loss: 1.8521 - val_hour_output_accuracy: 0.3872 - val_hour_output_loss: 19.2630 - val_loss: 21.1723 - val_minute_output_common_sense_metric_minute: 10.9078 - val_minute_output_loss: 1.8020
# Epoch 27/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3269 - hour_output_loss: 20.9990 - loss: 22.9351 - minute_output_common_sense_metric_minute: 10.9029 - minute_output_loss: 1.7985 - val_hour_output_accuracy: 0.4011 - val_hour_output_loss: 18.9596 - val_loss: 20.8239 - val_minute_output_common_sense_metric_minute: 10.7518 - val_minute_output_loss: 1.7449
# Epoch 28/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3405 - hour_output_loss: 20.5955 - loss: 22.5235 - minute_output_common_sense_metric_minute: 10.9251 - minute_output_loss: 1.7848 - val_hour_output_accuracy: 0.4211 - val_hour_output_loss: 18.3658 - val_loss: 20.2315 - val_minute_output_common_sense_metric_minute: 10.6392 - val_minute_output_loss: 1.7292
# Epoch 29/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3532 - hour_output_loss: 20.0001 - loss: 21.8930 - minute_output_common_sense_metric_minute: 10.7003 - minute_output_loss: 1.7444 - val_hour_output_accuracy: 0.4383 - val_hour_output_loss: 17.6865 - val_loss: 19.5041 - val_minute_output_common_sense_metric_minute: 10.5353 - val_minute_output_loss: 1.6970
# Epoch 30/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3597 - hour_output_loss: 19.6999 - loss: 21.5195 - minute_output_common_sense_metric_minute: 10.3813 - minute_output_loss: 1.6660 - val_hour_output_accuracy: 0.4556 - val_hour_output_loss: 17.2717 - val_loss: 19.0763 - val_minute_output_common_sense_metric_minute: 10.4506 - val_minute_output_loss: 1.6731
# Epoch 31/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3628 - hour_output_loss: 19.3412 - loss: 21.1686 - minute_output_common_sense_metric_minute: 10.4318 - minute_output_loss: 1.6689 - val_hour_output_accuracy: 0.4678 - val_hour_output_loss: 16.9401 - val_loss: 18.7027 - val_minute_output_common_sense_metric_minute: 10.2878 - val_minute_output_loss: 1.6321
# Epoch 32/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3832 - hour_output_loss: 18.9651 - loss: 20.7735 - minute_output_common_sense_metric_minute: 10.3250 - minute_output_loss: 1.6444 - val_hour_output_accuracy: 0.4972 - val_hour_output_loss: 16.2563 - val_loss: 17.9577 - val_minute_output_common_sense_metric_minute: 10.0134 - val_minute_output_loss: 1.5526
# Epoch 33/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3925 - hour_output_loss: 18.6660 - loss: 20.4349 - minute_output_common_sense_metric_minute: 10.1382 - minute_output_loss: 1.5998 - val_hour_output_accuracy: 0.5078 - val_hour_output_loss: 15.8804 - val_loss: 17.5492 - val_minute_output_common_sense_metric_minute: 9.8030 - val_minute_output_loss: 1.5149
# Epoch 34/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.3997 - hour_output_loss: 18.2903 - loss: 20.0144 - minute_output_common_sense_metric_minute: 9.9674 - minute_output_loss: 1.5499 - val_hour_output_accuracy: 0.5233 - val_hour_output_loss: 15.5901 - val_loss: 17.2431 - val_minute_output_common_sense_metric_minute: 9.7597 - val_minute_output_loss: 1.4986
# Epoch 35/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4151 - hour_output_loss: 17.8251 - loss: 19.5197 - minute_output_common_sense_metric_minute: 9.7881 - minute_output_loss: 1.5155 - val_hour_output_accuracy: 0.5272 - val_hour_output_loss: 15.1758 - val_loss: 16.7891 - val_minute_output_common_sense_metric_minute: 9.6184 - val_minute_output_loss: 1.4510
# Epoch 36/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4299 - hour_output_loss: 17.5086 - loss: 19.1565 - minute_output_common_sense_metric_minute: 9.6075 - minute_output_loss: 1.4636 - val_hour_output_accuracy: 0.5461 - val_hour_output_loss: 14.8322 - val_loss: 16.4068 - val_minute_output_common_sense_metric_minute: 9.3749 - val_minute_output_loss: 1.4006
# Epoch 37/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4280 - hour_output_loss: 17.3057 - loss: 18.9161 - minute_output_common_sense_metric_minute: 9.4294 - minute_output_loss: 1.4211 - val_hour_output_accuracy: 0.5606 - val_hour_output_loss: 14.3162 - val_loss: 15.8512 - val_minute_output_common_sense_metric_minute: 9.0859 - val_minute_output_loss: 1.3582
# Epoch 38/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4381 - hour_output_loss: 16.9305 - loss: 18.5080 - minute_output_common_sense_metric_minute: 9.2690 - minute_output_loss: 1.3834 - val_hour_output_accuracy: 0.5639 - val_hour_output_loss: 14.1132 - val_loss: 15.6352 - val_minute_output_common_sense_metric_minute: 9.0565 - val_minute_output_loss: 1.3470
# Epoch 39/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4529 - hour_output_loss: 16.7574 - loss: 18.3609 - minute_output_common_sense_metric_minute: 9.3181 - minute_output_loss: 1.4045 - val_hour_output_accuracy: 0.5839 - val_hour_output_loss: 13.8654 - val_loss: 15.3497 - val_minute_output_common_sense_metric_minute: 8.9267 - val_minute_output_loss: 1.3150
# Epoch 40/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4591 - hour_output_loss: 16.4689 - loss: 18.0441 - minute_output_common_sense_metric_minute: 9.1603 - minute_output_loss: 1.3715 - val_hour_output_accuracy: 0.5789 - val_hour_output_loss: 13.4538 - val_loss: 14.9533 - val_minute_output_common_sense_metric_minute: 8.9397 - val_minute_output_loss: 1.3184
# Epoch 41/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4697 - hour_output_loss: 16.0831 - loss: 17.6255 - minute_output_common_sense_metric_minute: 9.0924 - minute_output_loss: 1.3343 - val_hour_output_accuracy: 0.5967 - val_hour_output_loss: 13.2523 - val_loss: 14.7195 - val_minute_output_common_sense_metric_minute: 8.7610 - val_minute_output_loss: 1.2820
# Epoch 42/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4712 - hour_output_loss: 16.0722 - loss: 17.5793 - minute_output_common_sense_metric_minute: 8.8397 - minute_output_loss: 1.2941 - val_hour_output_accuracy: 0.6028 - val_hour_output_loss: 12.9745 - val_loss: 14.4044 - val_minute_output_common_sense_metric_minute: 8.5971 - val_minute_output_loss: 1.2449
# Epoch 43/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4821 - hour_output_loss: 15.7465 - loss: 17.2426 - minute_output_common_sense_metric_minute: 8.7910 - minute_output_loss: 1.2784 - val_hour_output_accuracy: 0.6250 - val_hour_output_loss: 12.4591 - val_loss: 13.8757 - val_minute_output_common_sense_metric_minute: 8.5324 - val_minute_output_loss: 1.2197
# Epoch 44/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4997 - hour_output_loss: 15.2946 - loss: 16.7546 - minute_output_common_sense_metric_minute: 8.6682 - minute_output_loss: 1.2376 - val_hour_output_accuracy: 0.6344 - val_hour_output_loss: 12.2057 - val_loss: 13.6271 - val_minute_output_common_sense_metric_minute: 8.4609 - val_minute_output_loss: 1.2161
# Epoch 45/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.4919 - hour_output_loss: 15.1614 - loss: 16.6432 - minute_output_common_sense_metric_minute: 8.6929 - minute_output_loss: 1.2549 - val_hour_output_accuracy: 0.6489 - val_hour_output_loss: 11.9952 - val_loss: 13.3743 - val_minute_output_common_sense_metric_minute: 8.2046 - val_minute_output_loss: 1.1683
# Epoch 46/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5078 - hour_output_loss: 14.9289 - loss: 16.3861 - minute_output_common_sense_metric_minute: 8.5560 - minute_output_loss: 1.2258 - val_hour_output_accuracy: 0.6461 - val_hour_output_loss: 11.6654 - val_loss: 13.0448 - val_minute_output_common_sense_metric_minute: 8.2528 - val_minute_output_loss: 1.1636
# Epoch 47/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5072 - hour_output_loss: 14.8092 - loss: 16.2409 - minute_output_common_sense_metric_minute: 8.4318 - minute_output_loss: 1.1957 - val_hour_output_accuracy: 0.6767 - val_hour_output_loss: 11.3983 - val_loss: 12.7721 - val_minute_output_common_sense_metric_minute: 8.2182 - val_minute_output_loss: 1.1454
# Epoch 48/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5267 - hour_output_loss: 14.3997 - loss: 15.7997 - minute_output_common_sense_metric_minute: 8.3183 - minute_output_loss: 1.1599 - val_hour_output_accuracy: 0.6800 - val_hour_output_loss: 11.2447 - val_loss: 12.5775 - val_minute_output_common_sense_metric_minute: 7.9880 - val_minute_output_loss: 1.1088
# Epoch 49/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5259 - hour_output_loss: 14.3506 - loss: 15.7933 - minute_output_common_sense_metric_minute: 8.4284 - minute_output_loss: 1.1982 - val_hour_output_accuracy: 0.6828 - val_hour_output_loss: 11.3151 - val_loss: 12.6962 - val_minute_output_common_sense_metric_minute: 8.1543 - val_minute_output_loss: 1.1516
# Epoch 50/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5373 - hour_output_loss: 13.8724 - loss: 15.2890 - minute_output_common_sense_metric_minute: 8.3188 - minute_output_loss: 1.1679 - val_hour_output_accuracy: 0.6917 - val_hour_output_loss: 10.7623 - val_loss: 12.0969 - val_minute_output_common_sense_metric_minute: 7.8596 - val_minute_output_loss: 1.0961
# Epoch 51/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5486 - hour_output_loss: 13.9194 - loss: 15.2842 - minute_output_common_sense_metric_minute: 8.1094 - minute_output_loss: 1.1119 - val_hour_output_accuracy: 0.6989 - val_hour_output_loss: 10.6494 - val_loss: 11.9430 - val_minute_output_common_sense_metric_minute: 7.7296 - val_minute_output_loss: 1.0594
# Epoch 52/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5370 - hour_output_loss: 13.9360 - loss: 15.3195 - minute_output_common_sense_metric_minute: 8.1115 - minute_output_loss: 1.1264 - val_hour_output_accuracy: 0.6961 - val_hour_output_loss: 10.7451 - val_loss: 12.0492 - val_minute_output_common_sense_metric_minute: 7.7583 - val_minute_output_loss: 1.0628
# Epoch 53/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5602 - hour_output_loss: 13.5142 - loss: 14.8962 - minute_output_common_sense_metric_minute: 8.0436 - minute_output_loss: 1.1205 - val_hour_output_accuracy: 0.7050 - val_hour_output_loss: 10.2658 - val_loss: 11.5522 - val_minute_output_common_sense_metric_minute: 7.5910 - val_minute_output_loss: 1.0301
# Epoch 54/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5563 - hour_output_loss: 13.6146 - loss: 14.9600 - minute_output_common_sense_metric_minute: 7.9035 - minute_output_loss: 1.0798 - val_hour_output_accuracy: 0.7206 - val_hour_output_loss: 10.0714 - val_loss: 11.3288 - val_minute_output_common_sense_metric_minute: 7.4305 - val_minute_output_loss: 0.9973
# Epoch 55/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5490 - hour_output_loss: 13.3806 - loss: 14.7426 - minute_output_common_sense_metric_minute: 7.9382 - minute_output_loss: 1.0924 - val_hour_output_accuracy: 0.7256 - val_hour_output_loss: 10.0090 - val_loss: 11.2524 - val_minute_output_common_sense_metric_minute: 7.3723 - val_minute_output_loss: 0.9855
# Epoch 56/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5701 - hour_output_loss: 13.1681 - loss: 14.5023 - minute_output_common_sense_metric_minute: 7.8158 - minute_output_loss: 1.0605 - val_hour_output_accuracy: 0.7278 - val_hour_output_loss: 9.7083 - val_loss: 10.9779 - val_minute_output_common_sense_metric_minute: 7.4881 - val_minute_output_loss: 1.0066
# Epoch 57/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5759 - hour_output_loss: 13.0787 - loss: 14.3919 - minute_output_common_sense_metric_minute: 7.7927 - minute_output_loss: 1.0357 - val_hour_output_accuracy: 0.7278 - val_hour_output_loss: 9.5630 - val_loss: 10.7809 - val_minute_output_common_sense_metric_minute: 7.2840 - val_minute_output_loss: 0.9551
# Epoch 58/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5688 - hour_output_loss: 13.0100 - loss: 14.3168 - minute_output_common_sense_metric_minute: 7.6869 - minute_output_loss: 1.0253 - val_hour_output_accuracy: 0.7389 - val_hour_output_loss: 9.4858 - val_loss: 10.7209 - val_minute_output_common_sense_metric_minute: 7.2455 - val_minute_output_loss: 0.9710
# Epoch 59/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5729 - hour_output_loss: 12.8565 - loss: 14.1978 - minute_output_common_sense_metric_minute: 7.7920 - minute_output_loss: 1.0556 - val_hour_output_accuracy: 0.7444 - val_hour_output_loss: 9.3997 - val_loss: 10.6406 - val_minute_output_common_sense_metric_minute: 7.2035 - val_minute_output_loss: 0.9624
# Epoch 60/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5902 - hour_output_loss: 12.5644 - loss: 13.8568 - minute_output_common_sense_metric_minute: 7.5838 - minute_output_loss: 1.0029 - val_hour_output_accuracy: 0.7500 - val_hour_output_loss: 9.1841 - val_loss: 10.3949 - val_minute_output_common_sense_metric_minute: 7.0578 - val_minute_output_loss: 0.9335
# Epoch 61/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5783 - hour_output_loss: 12.5641 - loss: 13.8768 - minute_output_common_sense_metric_minute: 7.6403 - minute_output_loss: 1.0191 - val_hour_output_accuracy: 0.7606 - val_hour_output_loss: 8.9977 - val_loss: 10.1892 - val_minute_output_common_sense_metric_minute: 7.0341 - val_minute_output_loss: 0.9261
# Epoch 62/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5958 - hour_output_loss: 12.3845 - loss: 13.6964 - minute_output_common_sense_metric_minute: 7.5820 - minute_output_loss: 1.0145 - val_hour_output_accuracy: 0.7711 - val_hour_output_loss: 8.8118 - val_loss: 10.0037 - val_minute_output_common_sense_metric_minute: 6.9453 - val_minute_output_loss: 0.9098
# Epoch 63/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5878 - hour_output_loss: 12.4070 - loss: 13.6926 - minute_output_common_sense_metric_minute: 7.4740 - minute_output_loss: 0.9844 - val_hour_output_accuracy: 0.7711 - val_hour_output_loss: 8.7824 - val_loss: 9.9839 - val_minute_output_common_sense_metric_minute: 7.0252 - val_minute_output_loss: 0.9162
# Epoch 64/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5940 - hour_output_loss: 12.1773 - loss: 13.4533 - minute_output_common_sense_metric_minute: 7.3892 - minute_output_loss: 0.9711 - val_hour_output_accuracy: 0.7722 - val_hour_output_loss: 8.7270 - val_loss: 9.9219 - val_minute_output_common_sense_metric_minute: 6.9851 - val_minute_output_loss: 0.8967
# Epoch 65/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.5985 - hour_output_loss: 12.0430 - loss: 13.3226 - minute_output_common_sense_metric_minute: 7.4109 - minute_output_loss: 0.9711 - val_hour_output_accuracy: 0.7761 - val_hour_output_loss: 8.4846 - val_loss: 9.7002 - val_minute_output_common_sense_metric_minute: 6.9549 - val_minute_output_loss: 0.9202
# Epoch 66/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6120 - hour_output_loss: 11.8032 - loss: 13.0955 - minute_output_common_sense_metric_minute: 7.4502 - minute_output_loss: 0.9803 - val_hour_output_accuracy: 0.7783 - val_hour_output_loss: 8.3722 - val_loss: 9.5613 - val_minute_output_common_sense_metric_minute: 6.8529 - val_minute_output_loss: 0.8845
# Epoch 67/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6003 - hour_output_loss: 12.0596 - loss: 13.3086 - minute_output_common_sense_metric_minute: 7.2660 - minute_output_loss: 0.9333 - val_hour_output_accuracy: 0.7756 - val_hour_output_loss: 8.3111 - val_loss: 9.4738 - val_minute_output_common_sense_metric_minute: 6.7874 - val_minute_output_loss: 0.8683
# Epoch 68/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.6023 - hour_output_loss: 11.7747 - loss: 13.0508 - minute_output_common_sense_metric_minute: 7.3291 - minute_output_loss: 0.9570 - val_hour_output_accuracy: 0.7839 - val_hour_output_loss: 8.2336 - val_loss: 9.4070 - val_minute_output_common_sense_metric_minute: 6.7073 - val_minute_output_loss: 0.8534
# Epoch 69/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6160 - hour_output_loss: 11.6734 - loss: 12.9321 - minute_output_common_sense_metric_minute: 7.2221 - minute_output_loss: 0.9359 - val_hour_output_accuracy: 0.7844 - val_hour_output_loss: 8.1062 - val_loss: 9.3032 - val_minute_output_common_sense_metric_minute: 6.7855 - val_minute_output_loss: 0.8764
# Epoch 70/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6230 - hour_output_loss: 11.4976 - loss: 12.7309 - minute_output_common_sense_metric_minute: 7.1042 - minute_output_loss: 0.9068 - val_hour_output_accuracy: 0.7911 - val_hour_output_loss: 7.9291 - val_loss: 9.1268 - val_minute_output_common_sense_metric_minute: 6.7519 - val_minute_output_loss: 0.8628
# Epoch 71/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.6240 - hour_output_loss: 11.4320 - loss: 12.6883 - minute_output_common_sense_metric_minute: 7.2482 - minute_output_loss: 0.9263 - val_hour_output_accuracy: 0.7989 - val_hour_output_loss: 7.9112 - val_loss: 9.0498 - val_minute_output_common_sense_metric_minute: 6.6195 - val_minute_output_loss: 0.8315
# Epoch 72/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6226 - hour_output_loss: 11.5002 - loss: 12.7369 - minute_output_common_sense_metric_minute: 7.0920 - minute_output_loss: 0.9030 - val_hour_output_accuracy: 0.8050 - val_hour_output_loss: 7.6736 - val_loss: 8.8148 - val_minute_output_common_sense_metric_minute: 6.4304 - val_minute_output_loss: 0.8014
# Epoch 73/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6226 - hour_output_loss: 11.2583 - loss: 12.5054 - minute_output_common_sense_metric_minute: 7.1397 - minute_output_loss: 0.9099 - val_hour_output_accuracy: 0.8056 - val_hour_output_loss: 7.6031 - val_loss: 8.7629 - val_minute_output_common_sense_metric_minute: 6.5278 - val_minute_output_loss: 0.8211
# Epoch 74/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.6397 - hour_output_loss: 10.9843 - loss: 12.2240 - minute_output_common_sense_metric_minute: 7.0976 - minute_output_loss: 0.8992 - val_hour_output_accuracy: 0.8100 - val_hour_output_loss: 7.6381 - val_loss: 8.8151 - val_minute_output_common_sense_metric_minute: 6.6519 - val_minute_output_loss: 0.8349
# Epoch 75/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6389 - hour_output_loss: 10.9592 - loss: 12.1955 - minute_output_common_sense_metric_minute: 7.0590 - minute_output_loss: 0.8924 - val_hour_output_accuracy: 0.8156 - val_hour_output_loss: 7.5954 - val_loss: 8.7467 - val_minute_output_common_sense_metric_minute: 6.5042 - val_minute_output_loss: 0.8097
# Epoch 76/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6354 - hour_output_loss: 10.9981 - loss: 12.2016 - minute_output_common_sense_metric_minute: 6.9514 - minute_output_loss: 0.8562 - val_hour_output_accuracy: 0.8172 - val_hour_output_loss: 7.3455 - val_loss: 8.4957 - val_minute_output_common_sense_metric_minute: 6.4812 - val_minute_output_loss: 0.8192
# Epoch 77/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6373 - hour_output_loss: 10.9051 - loss: 12.1127 - minute_output_common_sense_metric_minute: 6.8758 - minute_output_loss: 0.8569 - val_hour_output_accuracy: 0.8244 - val_hour_output_loss: 7.2649 - val_loss: 8.4069 - val_minute_output_common_sense_metric_minute: 6.4566 - val_minute_output_loss: 0.8080
# Epoch 78/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6403 - hour_output_loss: 10.9145 - loss: 12.1473 - minute_output_common_sense_metric_minute: 7.0106 - minute_output_loss: 0.8789 - val_hour_output_accuracy: 0.8200 - val_hour_output_loss: 7.1863 - val_loss: 8.3406 - val_minute_output_common_sense_metric_minute: 6.4117 - val_minute_output_loss: 0.8008
# Epoch 79/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6499 - hour_output_loss: 10.5670 - loss: 11.7851 - minute_output_common_sense_metric_minute: 6.8726 - minute_output_loss: 0.8611 - val_hour_output_accuracy: 0.8250 - val_hour_output_loss: 7.2356 - val_loss: 8.3930 - val_minute_output_common_sense_metric_minute: 6.4137 - val_minute_output_loss: 0.8000
# Epoch 80/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6446 - hour_output_loss: 10.6597 - loss: 11.8614 - minute_output_common_sense_metric_minute: 6.8346 - minute_output_loss: 0.8414 - val_hour_output_accuracy: 0.8128 - val_hour_output_loss: 7.1516 - val_loss: 8.2981 - val_minute_output_common_sense_metric_minute: 6.3697 - val_minute_output_loss: 0.7836
# Epoch 81/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.6419 - hour_output_loss: 10.8229 - loss: 12.0361 - minute_output_common_sense_metric_minute: 6.8331 - minute_output_loss: 0.8496 - val_hour_output_accuracy: 0.8161 - val_hour_output_loss: 7.2306 - val_loss: 8.3705 - val_minute_output_common_sense_metric_minute: 6.3366 - val_minute_output_loss: 0.7914
# Epoch 82/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6568 - hour_output_loss: 10.4776 - loss: 11.6720 - minute_output_common_sense_metric_minute: 6.7724 - minute_output_loss: 0.8277 - val_hour_output_accuracy: 0.8239 - val_hour_output_loss: 7.0105 - val_loss: 8.1496 - val_minute_output_common_sense_metric_minute: 6.3265 - val_minute_output_loss: 0.7744
# Epoch 83/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6485 - hour_output_loss: 10.5532 - loss: 11.7946 - minute_output_common_sense_metric_minute: 6.8746 - minute_output_loss: 0.8718 - val_hour_output_accuracy: 0.8294 - val_hour_output_loss: 6.9571 - val_loss: 8.0954 - val_minute_output_common_sense_metric_minute: 6.2793 - val_minute_output_loss: 0.7704
# Epoch 84/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6497 - hour_output_loss: 10.3755 - loss: 11.5744 - minute_output_common_sense_metric_minute: 6.7336 - minute_output_loss: 0.8262 - val_hour_output_accuracy: 0.8328 - val_hour_output_loss: 6.7449 - val_loss: 7.9183 - val_minute_output_common_sense_metric_minute: 6.4087 - val_minute_output_loss: 0.7964
# Epoch 85/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6654 - hour_output_loss: 10.1927 - loss: 11.3940 - minute_output_common_sense_metric_minute: 6.7344 - minute_output_loss: 0.8255 - val_hour_output_accuracy: 0.8333 - val_hour_output_loss: 6.7241 - val_loss: 7.8612 - val_minute_output_common_sense_metric_minute: 6.2992 - val_minute_output_loss: 0.7742
# Epoch 86/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6639 - hour_output_loss: 10.1846 - loss: 11.3639 - minute_output_common_sense_metric_minute: 6.6604 - minute_output_loss: 0.8003 - val_hour_output_accuracy: 0.8383 - val_hour_output_loss: 6.7849 - val_loss: 7.9099 - val_minute_output_common_sense_metric_minute: 6.1593 - val_minute_output_loss: 0.7422
# Epoch 87/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6612 - hour_output_loss: 10.0976 - loss: 11.3342 - minute_output_common_sense_metric_minute: 6.8319 - minute_output_loss: 0.8546 - val_hour_output_accuracy: 0.8417 - val_hour_output_loss: 6.6529 - val_loss: 7.7985 - val_minute_output_common_sense_metric_minute: 6.2295 - val_minute_output_loss: 0.7592
# Epoch 88/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6726 - hour_output_loss: 9.9419 - loss: 11.1515 - minute_output_common_sense_metric_minute: 6.7329 - minute_output_loss: 0.8247 - val_hour_output_accuracy: 0.8367 - val_hour_output_loss: 6.6190 - val_loss: 7.7921 - val_minute_output_common_sense_metric_minute: 6.3603 - val_minute_output_loss: 0.7852
# Epoch 89/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6715 - hour_output_loss: 10.0378 - loss: 11.2161 - minute_output_common_sense_metric_minute: 6.5423 - minute_output_loss: 0.7903 - val_hour_output_accuracy: 0.8439 - val_hour_output_loss: 6.5028 - val_loss: 7.6341 - val_minute_output_common_sense_metric_minute: 6.2745 - val_minute_output_loss: 0.7542
# Epoch 90/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6657 - hour_output_loss: 10.0973 - loss: 11.2874 - minute_output_common_sense_metric_minute: 6.6196 - minute_output_loss: 0.7993 - val_hour_output_accuracy: 0.8422 - val_hour_output_loss: 6.6722 - val_loss: 7.7919 - val_minute_output_common_sense_metric_minute: 6.1015 - val_minute_output_loss: 0.7433
# Epoch 91/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - hour_output_accuracy: 0.6650 - hour_output_loss: 10.0226 - loss: 11.2255 - minute_output_common_sense_metric_minute: 6.6270 - minute_output_loss: 0.8090 - val_hour_output_accuracy: 0.8433 - val_hour_output_loss: 6.6769 - val_loss: 7.8242 - val_minute_output_common_sense_metric_minute: 6.1443 - val_minute_output_loss: 0.7560
# Epoch 92/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6709 - hour_output_loss: 9.8220 - loss: 11.0185 - minute_output_common_sense_metric_minute: 6.5942 - minute_output_loss: 0.7997 - val_hour_output_accuracy: 0.8378 - val_hour_output_loss: 6.4275 - val_loss: 7.5562 - val_minute_output_common_sense_metric_minute: 6.0461 - val_minute_output_loss: 0.7369
# Epoch 93/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6727 - hour_output_loss: 9.9984 - loss: 11.1879 - minute_output_common_sense_metric_minute: 6.5543 - minute_output_loss: 0.7899 - val_hour_output_accuracy: 0.8422 - val_hour_output_loss: 6.4098 - val_loss: 7.5284 - val_minute_output_common_sense_metric_minute: 6.0743 - val_minute_output_loss: 0.7284
# Epoch 94/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6701 - hour_output_loss: 9.8130 - loss: 10.9939 - minute_output_common_sense_metric_minute: 6.5105 - minute_output_loss: 0.7784 - val_hour_output_accuracy: 0.8411 - val_hour_output_loss: 6.2929 - val_loss: 7.4168 - val_minute_output_common_sense_metric_minute: 6.0953 - val_minute_output_loss: 0.7291
# Epoch 95/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6800 - hour_output_loss: 9.7841 - loss: 10.9727 - minute_output_common_sense_metric_minute: 6.5255 - minute_output_loss: 0.7832 - val_hour_output_accuracy: 0.8500 - val_hour_output_loss: 6.2670 - val_loss: 7.3709 - val_minute_output_common_sense_metric_minute: 5.9361 - val_minute_output_loss: 0.7085
# Epoch 96/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6747 - hour_output_loss: 9.7692 - loss: 10.9388 - minute_output_common_sense_metric_minute: 6.4087 - minute_output_loss: 0.7614 - val_hour_output_accuracy: 0.8417 - val_hour_output_loss: 6.3218 - val_loss: 7.4583 - val_minute_output_common_sense_metric_minute: 6.0838 - val_minute_output_loss: 0.7269
# Epoch 97/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6840 - hour_output_loss: 9.5316 - loss: 10.6995 - minute_output_common_sense_metric_minute: 6.4477 - minute_output_loss: 0.7569 - val_hour_output_accuracy: 0.8450 - val_hour_output_loss: 6.1763 - val_loss: 7.2929 - val_minute_output_common_sense_metric_minute: 5.9416 - val_minute_output_loss: 0.7008
# Epoch 98/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6813 - hour_output_loss: 9.6235 - loss: 10.8079 - minute_output_common_sense_metric_minute: 6.4813 - minute_output_loss: 0.7705 - val_hour_output_accuracy: 0.8483 - val_hour_output_loss: 6.1972 - val_loss: 7.3262 - val_minute_output_common_sense_metric_minute: 5.9477 - val_minute_output_loss: 0.7139
# Epoch 99/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6870 - hour_output_loss: 9.5493 - loss: 10.7375 - minute_output_common_sense_metric_minute: 6.4636 - minute_output_loss: 0.7717 - val_hour_output_accuracy: 0.8533 - val_hour_output_loss: 6.1865 - val_loss: 7.2926 - val_minute_output_common_sense_metric_minute: 5.8626 - val_minute_output_loss: 0.6937
# Epoch 100/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6747 - hour_output_loss: 9.7285 - loss: 10.9066 - minute_output_common_sense_metric_minute: 6.4016 - minute_output_loss: 0.7587 - val_hour_output_accuracy: 0.8544 - val_hour_output_loss: 6.1152 - val_loss: 7.2350 - val_minute_output_common_sense_metric_minute: 5.9816 - val_minute_output_loss: 0.7083
# Epoch 101/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6799 - hour_output_loss: 9.5333 - loss: 10.7097 - minute_output_common_sense_metric_minute: 6.4115 - minute_output_loss: 0.7544 - val_hour_output_accuracy: 0.8533 - val_hour_output_loss: 5.9344 - val_loss: 7.0503 - val_minute_output_common_sense_metric_minute: 5.9403 - val_minute_output_loss: 0.7071
# Epoch 102/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6938 - hour_output_loss: 9.3131 - loss: 10.5004 - minute_output_common_sense_metric_minute: 6.4382 - minute_output_loss: 0.7626 - val_hour_output_accuracy: 0.8550 - val_hour_output_loss: 6.0132 - val_loss: 7.1186 - val_minute_output_common_sense_metric_minute: 5.8279 - val_minute_output_loss: 0.6967
# Epoch 103/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6892 - hour_output_loss: 9.2254 - loss: 10.3998 - minute_output_common_sense_metric_minute: 6.2904 - minute_output_loss: 0.7468 - val_hour_output_accuracy: 0.8589 - val_hour_output_loss: 5.8171 - val_loss: 6.9375 - val_minute_output_common_sense_metric_minute: 5.9694 - val_minute_output_loss: 0.7185
# Epoch 104/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6905 - hour_output_loss: 9.3584 - loss: 10.5153 - minute_output_common_sense_metric_minute: 6.2476 - minute_output_loss: 0.7270 - val_hour_output_accuracy: 0.8578 - val_hour_output_loss: 5.9037 - val_loss: 7.0164 - val_minute_output_common_sense_metric_minute: 5.8378 - val_minute_output_loss: 0.6868
# Epoch 105/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6885 - hour_output_loss: 9.4024 - loss: 10.5672 - minute_output_common_sense_metric_minute: 6.2550 - minute_output_loss: 0.7324 - val_hour_output_accuracy: 0.8561 - val_hour_output_loss: 5.9020 - val_loss: 7.0017 - val_minute_output_common_sense_metric_minute: 5.7969 - val_minute_output_loss: 0.6840
# Epoch 106/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6977 - hour_output_loss: 9.0364 - loss: 10.1666 - minute_output_common_sense_metric_minute: 6.1295 - minute_output_loss: 0.6953 - val_hour_output_accuracy: 0.8661 - val_hour_output_loss: 5.7227 - val_loss: 6.8435 - val_minute_output_common_sense_metric_minute: 5.8155 - val_minute_output_loss: 0.6881
# Epoch 107/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6971 - hour_output_loss: 9.2547 - loss: 10.4398 - minute_output_common_sense_metric_minute: 6.3335 - minute_output_loss: 0.7476 - val_hour_output_accuracy: 0.8683 - val_hour_output_loss: 5.6496 - val_loss: 6.7388 - val_minute_output_common_sense_metric_minute: 5.7172 - val_minute_output_loss: 0.6739
# Epoch 108/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6992 - hour_output_loss: 9.0737 - loss: 10.2327 - minute_output_common_sense_metric_minute: 6.2090 - minute_output_loss: 0.7188 - val_hour_output_accuracy: 0.8678 - val_hour_output_loss: 5.7437 - val_loss: 6.8648 - val_minute_output_common_sense_metric_minute: 5.8343 - val_minute_output_loss: 0.6867
# Epoch 109/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6975 - hour_output_loss: 9.1382 - loss: 10.3348 - minute_output_common_sense_metric_minute: 6.3385 - minute_output_loss: 0.7537 - val_hour_output_accuracy: 0.8611 - val_hour_output_loss: 5.7079 - val_loss: 6.8190 - val_minute_output_common_sense_metric_minute: 5.7987 - val_minute_output_loss: 0.6774
# Epoch 110/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6993 - hour_output_loss: 9.0574 - loss: 10.2538 - minute_output_common_sense_metric_minute: 6.3445 - minute_output_loss: 0.7511 - val_hour_output_accuracy: 0.8617 - val_hour_output_loss: 5.6388 - val_loss: 6.7755 - val_minute_output_common_sense_metric_minute: 5.8375 - val_minute_output_loss: 0.6923
# Epoch 111/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6985 - hour_output_loss: 9.0082 - loss: 10.1846 - minute_output_common_sense_metric_minute: 6.2429 - minute_output_loss: 0.7286 - val_hour_output_accuracy: 0.8767 - val_hour_output_loss: 5.5589 - val_loss: 6.6797 - val_minute_output_common_sense_metric_minute: 5.8136 - val_minute_output_loss: 0.6851
# Epoch 112/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.7027 - hour_output_loss: 8.9682 - loss: 10.1512 - minute_output_common_sense_metric_minute: 6.2713 - minute_output_loss: 0.7327 - val_hour_output_accuracy: 0.8667 - val_hour_output_loss: 5.6259 - val_loss: 6.7453 - val_minute_output_common_sense_metric_minute: 5.7759 - val_minute_output_loss: 0.6790
# Epoch 113/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.6971 - hour_output_loss: 9.0328 - loss: 10.1930 - minute_output_common_sense_metric_minute: 6.1423 - minute_output_loss: 0.7075 - val_hour_output_accuracy: 0.8711 - val_hour_output_loss: 5.5040 - val_loss: 6.6095 - val_minute_output_common_sense_metric_minute: 5.7636 - val_minute_output_loss: 0.6721
# Epoch 114/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.7060 - hour_output_loss: 8.9848 - loss: 10.1648 - minute_output_common_sense_metric_minute: 6.2375 - minute_output_loss: 0.7248 - val_hour_output_accuracy: 0.8739 - val_hour_output_loss: 5.4288 - val_loss: 6.5427 - val_minute_output_common_sense_metric_minute: 5.6397 - val_minute_output_loss: 0.6637
# Epoch 115/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.7058 - hour_output_loss: 8.8005 - loss: 9.9482 - minute_output_common_sense_metric_minute: 6.1259 - minute_output_loss: 0.6901 - val_hour_output_accuracy: 0.8772 - val_hour_output_loss: 5.4308 - val_loss: 6.5571 - val_minute_output_common_sense_metric_minute: 5.7363 - val_minute_output_loss: 0.6840
# Epoch 116/1000
# ...
# Epoch 961/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8679 - hour_output_loss: 4.1418 - loss: 5.2297 - minute_output_common_sense_metric_minute: 3.9474 - minute_output_loss: 0.3084 - val_hour_output_accuracy: 0.9550 - val_hour_output_loss: 2.0518 - val_loss: 3.1941 - val_minute_output_common_sense_metric_minute: 3.8820 - val_minute_output_loss: 0.3449
# Epoch 962/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8632 - hour_output_loss: 4.2218 - loss: 5.3098 - minute_output_common_sense_metric_minute: 4.0016 - minute_output_loss: 0.3084 - val_hour_output_accuracy: 0.9528 - val_hour_output_loss: 2.0372 - val_loss: 3.1617 - val_minute_output_common_sense_metric_minute: 3.7590 - val_minute_output_loss: 0.3259
# Epoch 963/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8637 - hour_output_loss: 4.3220 - loss: 5.3985 - minute_output_common_sense_metric_minute: 3.9213 - minute_output_loss: 0.2971 - val_hour_output_accuracy: 0.9506 - val_hour_output_loss: 2.0960 - val_loss: 3.2118 - val_minute_output_common_sense_metric_minute: 3.7286 - val_minute_output_loss: 0.3180
# Epoch 964/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8631 - hour_output_loss: 4.2474 - loss: 5.3351 - minute_output_common_sense_metric_minute: 3.9857 - minute_output_loss: 0.3083 - val_hour_output_accuracy: 0.9494 - val_hour_output_loss: 2.1531 - val_loss: 3.2714 - val_minute_output_common_sense_metric_minute: 3.8063 - val_minute_output_loss: 0.3242
# Epoch 965/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8650 - hour_output_loss: 4.2155 - loss: 5.2898 - minute_output_common_sense_metric_minute: 3.8920 - minute_output_loss: 0.2947 - val_hour_output_accuracy: 0.9489 - val_hour_output_loss: 2.1749 - val_loss: 3.2913 - val_minute_output_common_sense_metric_minute: 3.7093 - val_minute_output_loss: 0.3172
# Epoch 966/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8704 - hour_output_loss: 4.0930 - loss: 5.1552 - minute_output_common_sense_metric_minute: 3.8281 - minute_output_loss: 0.2825 - val_hour_output_accuracy: 0.9539 - val_hour_output_loss: 2.0819 - val_loss: 3.1936 - val_minute_output_common_sense_metric_minute: 3.6533 - val_minute_output_loss: 0.3154
# Epoch 967/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8722 - hour_output_loss: 4.0936 - loss: 5.1714 - minute_output_common_sense_metric_minute: 3.9267 - minute_output_loss: 0.2984 - val_hour_output_accuracy: 0.9544 - val_hour_output_loss: 2.0455 - val_loss: 3.1678 - val_minute_output_common_sense_metric_minute: 3.7567 - val_minute_output_loss: 0.3230
# Epoch 968/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8638 - hour_output_loss: 4.2329 - loss: 5.3052 - minute_output_common_sense_metric_minute: 3.8882 - minute_output_loss: 0.2929 - val_hour_output_accuracy: 0.9522 - val_hour_output_loss: 2.1147 - val_loss: 3.2394 - val_minute_output_common_sense_metric_minute: 3.8411 - val_minute_output_loss: 0.3306
# Epoch 969/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8642 - hour_output_loss: 4.2058 - loss: 5.2865 - minute_output_common_sense_metric_minute: 3.9303 - minute_output_loss: 0.3013 - val_hour_output_accuracy: 0.9528 - val_hour_output_loss: 2.0945 - val_loss: 3.2203 - val_minute_output_common_sense_metric_minute: 3.7502 - val_minute_output_loss: 0.3346
# Epoch 970/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8647 - hour_output_loss: 4.2209 - loss: 5.3064 - minute_output_common_sense_metric_minute: 3.9723 - minute_output_loss: 0.3062 - val_hour_output_accuracy: 0.9522 - val_hour_output_loss: 2.0260 - val_loss: 3.1384 - val_minute_output_common_sense_metric_minute: 3.7452 - val_minute_output_loss: 0.3185
# Epoch 971/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8660 - hour_output_loss: 4.0333 - loss: 5.0991 - minute_output_common_sense_metric_minute: 3.9041 - minute_output_loss: 0.2866 - val_hour_output_accuracy: 0.9506 - val_hour_output_loss: 2.1165 - val_loss: 3.2308 - val_minute_output_common_sense_metric_minute: 3.6985 - val_minute_output_loss: 0.3193
# Epoch 972/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8657 - hour_output_loss: 4.0769 - loss: 5.1559 - minute_output_common_sense_metric_minute: 3.9072 - minute_output_loss: 0.2999 - val_hour_output_accuracy: 0.9494 - val_hour_output_loss: 2.1287 - val_loss: 3.2660 - val_minute_output_common_sense_metric_minute: 3.8534 - val_minute_output_loss: 0.3435
# Epoch 973/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8668 - hour_output_loss: 4.1136 - loss: 5.1916 - minute_output_common_sense_metric_minute: 3.9408 - minute_output_loss: 0.2988 - val_hour_output_accuracy: 0.9522 - val_hour_output_loss: 2.1473 - val_loss: 3.2859 - val_minute_output_common_sense_metric_minute: 3.9375 - val_minute_output_loss: 0.3443
# Epoch 974/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8617 - hour_output_loss: 4.2393 - loss: 5.3226 - minute_output_common_sense_metric_minute: 3.9439 - minute_output_loss: 0.3041 - val_hour_output_accuracy: 0.9456 - val_hour_output_loss: 2.1996 - val_loss: 3.3375 - val_minute_output_common_sense_metric_minute: 3.8974 - val_minute_output_loss: 0.3421
# Epoch 975/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8623 - hour_output_loss: 4.2737 - loss: 5.3504 - minute_output_common_sense_metric_minute: 3.8982 - minute_output_loss: 0.2977 - val_hour_output_accuracy: 0.9500 - val_hour_output_loss: 2.0695 - val_loss: 3.1978 - val_minute_output_common_sense_metric_minute: 3.8500 - val_minute_output_loss: 0.3314
# Epoch 976/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8638 - hour_output_loss: 4.2128 - loss: 5.2877 - minute_output_common_sense_metric_minute: 3.9352 - minute_output_loss: 0.2960 - val_hour_output_accuracy: 0.9506 - val_hour_output_loss: 2.1174 - val_loss: 3.2342 - val_minute_output_common_sense_metric_minute: 3.7431 - val_minute_output_loss: 0.3200
# Epoch 977/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8670 - hour_output_loss: 4.1691 - loss: 5.2393 - minute_output_common_sense_metric_minute: 3.8910 - minute_output_loss: 0.2913 - val_hour_output_accuracy: 0.9511 - val_hour_output_loss: 2.1820 - val_loss: 3.3007 - val_minute_output_common_sense_metric_minute: 3.7244 - val_minute_output_loss: 0.3262
# Epoch 978/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8653 - hour_output_loss: 4.0960 - loss: 5.1784 - minute_output_common_sense_metric_minute: 3.9355 - minute_output_loss: 0.3034 - val_hour_output_accuracy: 0.9528 - val_hour_output_loss: 2.0980 - val_loss: 3.2261 - val_minute_output_common_sense_metric_minute: 3.8692 - val_minute_output_loss: 0.3377
# Epoch 979/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8611 - hour_output_loss: 4.1361 - loss: 5.2039 - minute_output_common_sense_metric_minute: 3.8785 - minute_output_loss: 0.2887 - val_hour_output_accuracy: 0.9444 - val_hour_output_loss: 2.1740 - val_loss: 3.2872 - val_minute_output_common_sense_metric_minute: 3.7288 - val_minute_output_loss: 0.3241
# Epoch 980/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8651 - hour_output_loss: 4.0817 - loss: 5.1440 - minute_output_common_sense_metric_minute: 3.8347 - minute_output_loss: 0.2831 - val_hour_output_accuracy: 0.9528 - val_hour_output_loss: 2.1788 - val_loss: 3.2825 - val_minute_output_common_sense_metric_minute: 3.6633 - val_minute_output_loss: 0.3101
# Epoch 981/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8654 - hour_output_loss: 4.2484 - loss: 5.3093 - minute_output_common_sense_metric_minute: 3.8233 - minute_output_loss: 0.2817 - val_hour_output_accuracy: 0.9467 - val_hour_output_loss: 2.1458 - val_loss: 3.2857 - val_minute_output_common_sense_metric_minute: 3.8436 - val_minute_output_loss: 0.3466
# Epoch 982/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8667 - hour_output_loss: 4.0907 - loss: 5.1555 - minute_output_common_sense_metric_minute: 3.8597 - minute_output_loss: 0.2856 - val_hour_output_accuracy: 0.9511 - val_hour_output_loss: 2.0993 - val_loss: 3.2207 - val_minute_output_common_sense_metric_minute: 3.7028 - val_minute_output_loss: 0.3285
# Epoch 983/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8674 - hour_output_loss: 4.0485 - loss: 5.1217 - minute_output_common_sense_metric_minute: 3.8524 - minute_output_loss: 0.2942 - val_hour_output_accuracy: 0.9494 - val_hour_output_loss: 2.1102 - val_loss: 3.2575 - val_minute_output_common_sense_metric_minute: 3.8301 - val_minute_output_loss: 0.3520
# Epoch 984/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8675 - hour_output_loss: 4.1171 - loss: 5.1859 - minute_output_common_sense_metric_minute: 3.8941 - minute_output_loss: 0.2899 - val_hour_output_accuracy: 0.9517 - val_hour_output_loss: 2.0814 - val_loss: 3.2046 - val_minute_output_common_sense_metric_minute: 3.7107 - val_minute_output_loss: 0.3236
# Epoch 985/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8663 - hour_output_loss: 4.0179 - loss: 5.0900 - minute_output_common_sense_metric_minute: 3.8958 - minute_output_loss: 0.2932 - val_hour_output_accuracy: 0.9539 - val_hour_output_loss: 2.1358 - val_loss: 3.2608 - val_minute_output_common_sense_metric_minute: 3.7962 - val_minute_output_loss: 0.3340
# Epoch 986/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8590 - hour_output_loss: 4.3842 - loss: 5.4610 - minute_output_common_sense_metric_minute: 3.8974 - minute_output_loss: 0.2978 - val_hour_output_accuracy: 0.9478 - val_hour_output_loss: 2.1179 - val_loss: 3.2311 - val_minute_output_common_sense_metric_minute: 3.8014 - val_minute_output_loss: 0.3199
# Epoch 987/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8730 - hour_output_loss: 4.0612 - loss: 5.1265 - minute_output_common_sense_metric_minute: 3.8288 - minute_output_loss: 0.2864 - val_hour_output_accuracy: 0.9494 - val_hour_output_loss: 2.2047 - val_loss: 3.3396 - val_minute_output_common_sense_metric_minute: 3.8256 - val_minute_output_loss: 0.3383
# Epoch 988/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8600 - hour_output_loss: 4.1872 - loss: 5.2661 - minute_output_common_sense_metric_minute: 3.9372 - minute_output_loss: 0.3001 - val_hour_output_accuracy: 0.9578 - val_hour_output_loss: 2.0191 - val_loss: 3.1387 - val_minute_output_common_sense_metric_minute: 3.7291 - val_minute_output_loss: 0.3248
# Epoch 989/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8672 - hour_output_loss: 4.1029 - loss: 5.1796 - minute_output_common_sense_metric_minute: 3.9252 - minute_output_loss: 0.2980 - val_hour_output_accuracy: 0.9528 - val_hour_output_loss: 2.0738 - val_loss: 3.1991 - val_minute_output_common_sense_metric_minute: 3.7248 - val_minute_output_loss: 0.3316
# Epoch 990/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8654 - hour_output_loss: 4.1849 - loss: 5.2593 - minute_output_common_sense_metric_minute: 3.9015 - minute_output_loss: 0.2956 - val_hour_output_accuracy: 0.9494 - val_hour_output_loss: 2.1225 - val_loss: 3.2321 - val_minute_output_common_sense_metric_minute: 3.7003 - val_minute_output_loss: 0.3106
# Epoch 991/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8614 - hour_output_loss: 4.2358 - loss: 5.3121 - minute_output_common_sense_metric_minute: 3.8820 - minute_output_loss: 0.2976 - val_hour_output_accuracy: 0.9583 - val_hour_output_loss: 1.9738 - val_loss: 3.0815 - val_minute_output_common_sense_metric_minute: 3.6647 - val_minute_output_loss: 0.3149
# Epoch 992/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8674 - hour_output_loss: 4.1252 - loss: 5.1862 - minute_output_common_sense_metric_minute: 3.8424 - minute_output_loss: 0.2824 - val_hour_output_accuracy: 0.9544 - val_hour_output_loss: 1.9250 - val_loss: 3.0457 - val_minute_output_common_sense_metric_minute: 3.7397 - val_minute_output_loss: 0.3252
# Epoch 993/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8679 - hour_output_loss: 4.0673 - loss: 5.1280 - minute_output_common_sense_metric_minute: 3.8468 - minute_output_loss: 0.2821 - val_hour_output_accuracy: 0.9517 - val_hour_output_loss: 2.0379 - val_loss: 3.1634 - val_minute_output_common_sense_metric_minute: 3.7852 - val_minute_output_loss: 0.3277
# Epoch 994/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8602 - hour_output_loss: 4.3295 - loss: 5.4121 - minute_output_common_sense_metric_minute: 3.9234 - minute_output_loss: 0.3039 - val_hour_output_accuracy: 0.9533 - val_hour_output_loss: 2.0224 - val_loss: 3.1304 - val_minute_output_common_sense_metric_minute: 3.7419 - val_minute_output_loss: 0.3143
# Epoch 995/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8592 - hour_output_loss: 4.2635 - loss: 5.3385 - minute_output_common_sense_metric_minute: 3.8785 - minute_output_loss: 0.2965 - val_hour_output_accuracy: 0.9517 - val_hour_output_loss: 2.0600 - val_loss: 3.1730 - val_minute_output_common_sense_metric_minute: 3.6946 - val_minute_output_loss: 0.3175
# Epoch 996/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8665 - hour_output_loss: 4.0656 - loss: 5.1311 - minute_output_common_sense_metric_minute: 3.8177 - minute_output_loss: 0.2871 - val_hour_output_accuracy: 0.9461 - val_hour_output_loss: 2.0745 - val_loss: 3.2147 - val_minute_output_common_sense_metric_minute: 3.8231 - val_minute_output_loss: 0.3417
# Epoch 997/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8675 - hour_output_loss: 4.0879 - loss: 5.1602 - minute_output_common_sense_metric_minute: 3.8976 - minute_output_loss: 0.2940 - val_hour_output_accuracy: 0.9511 - val_hour_output_loss: 2.0874 - val_loss: 3.2054 - val_minute_output_common_sense_metric_minute: 3.6838 - val_minute_output_loss: 0.3230
# Epoch 998/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8648 - hour_output_loss: 4.0651 - loss: 5.1427 - minute_output_common_sense_metric_minute: 3.8866 - minute_output_loss: 0.2991 - val_hour_output_accuracy: 0.9539 - val_hour_output_loss: 2.0674 - val_loss: 3.1904 - val_minute_output_common_sense_metric_minute: 3.8306 - val_minute_output_loss: 0.3339
# Epoch 999/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - hour_output_accuracy: 0.8674 - hour_output_loss: 4.1347 - loss: 5.2042 - minute_output_common_sense_metric_minute: 3.9093 - minute_output_loss: 0.2911 - val_hour_output_accuracy: 0.9472 - val_hour_output_loss: 2.0950 - val_loss: 3.2211 - val_minute_output_common_sense_metric_minute: 3.7081 - val_minute_output_loss: 0.3277
# Epoch 1000/1000
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - hour_output_accuracy: 0.8648 - hour_output_loss: 4.1460 - loss: 5.2174 - minute_output_common_sense_metric_minute: 3.8571 - minute_output_loss: 0.2929 - val_hour_output_accuracy: 0.9478 - val_hour_output_loss: 2.0694 - val_loss: 3.1690 - val_minute_output_common_sense_metric_minute: 3.6616 - val_minute_output_loss: 0.3053
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - hour_output_accuracy: 0.9541 - hour_output_loss: 1.7373 - loss: 2.8594 - minute_output_common_sense_metric_minute: 3.6648 - minute_output_loss: 0.3440
# Test Loss: 2.9170689582824707
# Hour Loss: 1.774484634399414, Hour Accuracy: 0.9527778029441833
# Minute Loss: 0.37340623140335083, Minute CSE: 3.8003461360931396
# 57/57 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Common Sense Error (CSE): 10.64 minutes
